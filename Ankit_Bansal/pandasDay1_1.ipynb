# %%
emp={'name':'Sudhanshu','Gender':'Male','email':'sudhanshur4746@gmail.com'}
emp
# Out:
# {'name': 'Sudhanshu', 'Gender': 'Male', 'email': 'sudhanshur4746@gmail.com'}

# %%
emp= {"name":["Ankit","Rahul","Priya"],"gender":["Male","Male","Female"], "email":["ankit@gmail.com","rahul@gmail.com","priya@gmail.com"] }
emp
# Out:
# {'name': ['Ankit', 'Rahul', 'Priya'],
#  'gender': ['Male', 'Male', 'Female'],
#  'email': ['ankit@gmail.com', 'rahul@gmail.com', 'priya@gmail.com']}

# %%
import pandas as pd

# %%
df_emp=pd.DataFrame(emp)
df_emp
# Out:
#     name  gender            email
# 0  Ankit    Male  ankit@gmail.com
# 1  Rahul    Male  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
df_emp['name']
# Out:
# 0    Ankit
# 1    Rahul
# 2    Priya
# Name: name, dtype: object

# %%
#another method to accessing the element 
df_emp.name
# Out:
# 0    Ankit
# 1    Rahul
# 2    Priya
# Name: name, dtype: object

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   gender  3 non-null      object
#  2   email   3 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
df_emp.describe()
# Out:
#          name gender            email
# count       3      3                3
# unique      3      2                3
# top     Ankit   Male  ankit@gmail.com
# freq        1      2                1

# %%
#iloc & loc for acessing the element row wise / iloc only use in indexing or integer value 
df_emp.iloc[0]
# Out:
# name                Ankit
# gender               Male
# email     ankit@gmail.com
# Name: 0, dtype: object

# %%
df_emp
# Out:
#     name  gender            email
# 0  Ankit    Male  ankit@gmail.com
# 1  Rahul    Male  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
df_emp.iloc[[0,2],0]
# Out:
# 0    Ankit
# 2    Priya
# Name: name, dtype: object

# %%
#specific rows/columns
df_emp.iloc[[0,2],[0,2]]
# Out:
#     name            email
# 0  Ankit  ankit@gmail.com
# 2  Priya  priya@gmail.com

# %%
#loc is labled based
df_emp
# Out:
#     name  gender            email
# 0  Ankit    Male  ankit@gmail.com
# 1  Rahul    Male  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
df_emp.loc[0,'name']
# Out:
# 'Ankit'

# %%
df_emp.loc[0,['name','email']]
# Out:
# name               Ankit
# email    ankit@gmail.com
# Name: 0, dtype: object

# %%
df_emp.loc[0:2,['name','email']]
# Out:
#     name            email
# 0  Ankit  ankit@gmail.com
# 1  Rahul  rahul@gmail.com
# 2  Priya  priya@gmail.com

# %%
df_emp.loc[0:2,'name':'email']
# Out:
#     name  gender            email
# 0  Ankit    Male  ankit@gmail.com
# 1  Rahul    Male  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
df_emp.set_index('email')
# Out:
#                   name  gender
# email
# ankit@gmail.com  Ankit    Male
# rahul@gmail.com  Rahul    Male
# priya@gmail.com  Priya  Female

# %%
df_emp
# Out:
#     name  gender            email
# 0  Ankit    Male  ankit@gmail.com
# 1  Rahul    Male  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
#if we want to change the our data frame according to inder then use inplace 
df_emp.set_index('email',inplace=True)

# %%
df_emp
# Out:
#                   name  gender
# email
# ankit@gmail.com  Ankit    Male
# rahul@gmail.com  Rahul    Male
# priya@gmail.com  Priya  Female

# %%
df_emp.sort_index()
df_emp.sort_index(ascending=False)
# Out:
#                   name  gender
# email
# rahul@gmail.com  Rahul    Male
# priya@gmail.com  Priya  Female
# ankit@gmail.com  Ankit    Male

# %%
df_emp.loc[['ankit@gmail.com','priya@gmail.com'],'name':'gender']
# Out:
#                   name  gender
# email
# ankit@gmail.com  Ankit    Male
# priya@gmail.com  Priya  Female

# %%
df_emp.reset_index(inplace=True)

# %%
df_emp
# Out:
#              email   name  gender
# 0  ankit@gmail.com  Ankit    Male
# 1  rahul@gmail.com  Rahul    Male
# 2  priya@gmail.com  Priya  Female

# %%
fc=(df_emp['gender']=='Male')

# %%
df_emp[fc]
# Out:
#                   name gender
# email
# ankit@gmail.com  Ankit   Male
# rahul@gmail.com  Rahul   Male

# %%
df_emp[(df_emp['gender']=='Male')]
# Out:
#                   name gender
# email
# ankit@gmail.com  Ankit   Male
# rahul@gmail.com  Rahul   Male

# %%
fci = ~(df_emp['gender']=='Male')

# %%
fci
# Out:
# email
# ankit@gmail.com    False
# rahul@gmail.com    False
# priya@gmail.com     True
# Name: gender, dtype: bool

# %%
df_emp[fci]
# Out:
#                   name  gender
# email
# priya@gmail.com  Priya  Female

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 fc = (df.category=='Furniture')
#
# NameError: name 'df' is not defined
