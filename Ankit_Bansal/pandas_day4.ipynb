# %%
import pandas as pd

# %%
df=pd.read_csv('orders.txt')
df
df.dtypes
# Out:
# order_id          object
# order_date        object
# customer_name     object
# city              object
# category          object
# product_id        object
# sales            float64
# profit           float64
# dtype: object

# %%
df=pd.read_csv('orders.txt',parse_dates=['order_date'])
df
# Out:
#             order_id order_date      customer_name           city  \
# 0     CA-2018-100006 2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090 2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293 2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328 2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363 2018-04-08        Jim Mitchum       Glendale
# ...              ...        ...                ...            ...
# 5004  US-2021-168802 2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320 2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488 2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502 2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551 2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
df.dtypes
# Out:
# order_id                 object
# order_date       datetime64[ns]
# customer_name            object
# city                     object
# category                 object
# product_id               object
# sales                   float64
# profit                  float64
# dtype: object

# %%
#another way of changing the data types
df=pd.read_csv('orders.txt')
df['order_date']=pd.to_datetime(df['order_date'])
df.dtypes
# Out:
# order_id                 object
# order_date       datetime64[ns]
# customer_name            object
# city                     object
# category                 object
# product_id               object
# sales                   float64
# profit                  float64
# dtype: object

# %%
dates = ['2020$04$05','2021$04$05']
pd.to_datetime(dates,format = '%Y$%m$%d')
# Out:
# DatetimeIndex(['2020-04-05', '2021-04-05'], dtype='datetime64[ns]', freq=None)

# %%
dates = ['2020-04-05','2021-04-05']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2020-04-05', '2021-04-05'], dtype='datetime64[ns]', freq=None)

# %%
dates = ['2020-04-05','2021/04/05']
pd.to_datetime(dates,format='mixed')
# Out:
# DatetimeIndex(['2020-04-05', '2021-04-05'], dtype='datetime64[ns]', freq=None)

# %%
df=pd.read_csv('orders.txt',parse_dates=['order_date'],index_col = 'order_date')
df
# Out:
#                   order_id      customer_name           city         category  \
# order_date
# 2018-09-07  CA-2018-100006        Dennis Kane  New York City       Technology
# 2018-07-08  CA-2018-100090         Ed Braxton  San Francisco        Furniture
# 2018-03-14  CA-2018-100293   Neil Französisch   Jacksonville  Office Supplies
# 2018-01-28  CA-2018-100328    Jasper Cacioppo  New York City  Office Supplies
# 2018-04-08  CA-2018-100363        Jim Mitchum       Glendale  Office Supplies
# ...                    ...                ...            ...              ...
# 2021-11-03  US-2021-168802      Jack O'Briant        Seattle  Office Supplies
# 2021-07-23  US-2021-169320     Lena Hernandez        Elkhart  Office Supplies
# 2021-09-07  US-2021-169488       Allen Armold     Providence  Office Supplies
# 2021-08-28  US-2021-169502  Matthew Grinstein      Milwaukee  Office Supplies
# 2021-07-07  US-2021-169551          Rob Lucas   Philadelphia        Furniture
#
# ...

# %%
df.loc['2018']
# Out:
#                   order_id      customer_name           city         category  \
# order_date
# 2018-09-07  CA-2018-100006        Dennis Kane  New York City       Technology
# 2018-07-08  CA-2018-100090         Ed Braxton  San Francisco        Furniture
# 2018-03-14  CA-2018-100293   Neil Französisch   Jacksonville  Office Supplies
# 2018-01-28  CA-2018-100328    Jasper Cacioppo  New York City  Office Supplies
# 2018-04-08  CA-2018-100363        Jim Mitchum       Glendale  Office Supplies
# ...                    ...                ...            ...              ...
# 2018-09-30  US-2018-167633        Ben Wallace  Boynton Beach  Office Supplies
# 2018-12-24  US-2018-167738    Julie Creighton    Los Angeles        Furniture
# 2018-11-21  US-2018-168501  Jason Klamczynski         Dallas  Office Supplies
# 2018-02-07  US-2018-169390    Chris Selesnick  New York City  Office Supplies
# 2018-12-30  US-2018-169789   Maureen Fritzler        Phoenix  Office Supplies
#
# ...

# %%
#finding the in the range with date function 
df.sort_index().loc['2020-01-01':'2020-01-05']
# Out:
#                   order_id      customer_name          city         category  \
# order_date
# 2020-01-02  CA-2020-160304      Brendan Murry  Gaithersburg        Furniture
# 2020-01-03  US-2020-116365  Christine Abelman   San Antonio       Technology
# 2020-01-03  CA-2020-125206       Lena Radford   Los Angeles  Office Supplies
# 2020-01-03  CA-2020-105207      Bill Overfelt  Broken Arrow        Furniture
# 2020-01-04  US-2020-164630         Erica Bern     Charlotte       Technology
# 2020-01-04  CA-2020-158211       Ben Peterman  Philadelphia  Office Supplies
# 2020-01-05  CA-2020-134474    Anthony Johnson  Jacksonville  Office Supplies
#
#                  product_id     sales    profit
# order_date
# 2020-01-02  FUR-BO-10004709   173.940   38.2668
# 2020-01-03  TEC-AC-10002217    30.080   -5.2640
# 2020-01-03  OFF-ST-10003692   114.460   28.6150
# 2020-01-03  FUR-TA-10000617  1592.850  350.4270
# 2020-01-04  TEC-CO-10000971   959.968  119.9960
# ...

# %%
#finding the in the range with date function using another form 
df.sort_index(inplace=True)

# %%
df.loc['2020-01-01':'2020-01-05']
# Out:
#                   order_id      customer_name          city         category  \
# order_date
# 2020-01-02  CA-2020-160304      Brendan Murry  Gaithersburg        Furniture
# 2020-01-03  US-2020-116365  Christine Abelman   San Antonio       Technology
# 2020-01-03  CA-2020-125206       Lena Radford   Los Angeles  Office Supplies
# 2020-01-03  CA-2020-105207      Bill Overfelt  Broken Arrow        Furniture
# 2020-01-04  US-2020-164630         Erica Bern     Charlotte       Technology
# 2020-01-04  CA-2020-158211       Ben Peterman  Philadelphia  Office Supplies
# 2020-01-05  CA-2020-134474    Anthony Johnson  Jacksonville  Office Supplies
#
#                  product_id     sales    profit
# order_date
# 2020-01-02  FUR-BO-10004709   173.940   38.2668
# 2020-01-03  TEC-AC-10002217    30.080   -5.2640
# 2020-01-03  OFF-ST-10003692   114.460   28.6150
# 2020-01-03  FUR-TA-10000617  1592.850  350.4270
# 2020-01-04  TEC-CO-10000971   959.968  119.9960
# ...

# %%
df.dtypes
# Out:
# order_id          object
# customer_name     object
# city              object
# category          object
# product_id        object
# sales            float64
# profit           float64
# dtype: object

# %%
df=pd.read_csv('orders.txt',parse_dates=['order_date'])
df
# Out:
#             order_id order_date      customer_name           city  \
# 0     CA-2018-100006 2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090 2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293 2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328 2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363 2018-04-08        Jim Mitchum       Glendale
# ...              ...        ...                ...            ...
# 5004  US-2021-168802 2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320 2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488 2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502 2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551 2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
df.dtypes
# Out:
# order_id                 object
# order_date       datetime64[ns]
# customer_name            object
# city                     object
# category                 object
# product_id               object
# sales                   float64
# profit                  float64
# dtype: object

# %%
df['year_date']=df['order_date'].dt.year

# %%
df
# Out:
#             order_id order_date      customer_name           city  \
# 0     CA-2018-100006 2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090 2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293 2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328 2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363 2018-04-08        Jim Mitchum       Glendale
# ...              ...        ...                ...            ...
# 5004  US-2021-168802 2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320 2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488 2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502 2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551 2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit  year_date
# 0          Technology  TEC-PH-10002075  377.970  109.6113       2018
# ...

# %%
df['order_date'].dt.month
# Out:
# 0        9
# 1        7
# 2        3
# 3        1
# 4        4
#         ..
# 5004    11
# 5005     7
# 5006     9
# 5007     8
# 5008     7
# Name: order_date, Length: 5009, dtype: int32

# %%
df['order_date'].dt.day_name()
# Out:
# 0          Friday
# 1          Sunday
# 2       Wednesday
# 3          Sunday
# 4          Sunday
#           ...
# 5004    Wednesday
# 5005       Friday
# 5006      Tuesday
# 5007     Saturday
# 5008    Wednesday
# Name: order_date, Length: 5009, dtype: object

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# %%
df.plot('category','sales')
# Out:
# <Axes: xlabel='category'>

# %%
df=pd.read_csv('orders.txt',parse_dates=['order_date'],index_col = 'order_date')
df
# Out:
#                   order_id      customer_name           city         category  \
# order_date
# 2018-09-07  CA-2018-100006        Dennis Kane  New York City       Technology
# 2018-07-08  CA-2018-100090         Ed Braxton  San Francisco        Furniture
# 2018-03-14  CA-2018-100293   Neil Französisch   Jacksonville  Office Supplies
# 2018-01-28  CA-2018-100328    Jasper Cacioppo  New York City  Office Supplies
# 2018-04-08  CA-2018-100363        Jim Mitchum       Glendale  Office Supplies
# ...                    ...                ...            ...              ...
# 2021-11-03  US-2021-168802      Jack O'Briant        Seattle  Office Supplies
# 2021-07-23  US-2021-169320     Lena Hernandez        Elkhart  Office Supplies
# 2021-09-07  US-2021-169488       Allen Armold     Providence  Office Supplies
# 2021-08-28  US-2021-169502  Matthew Grinstein      Milwaukee  Office Supplies
# 2021-07-07  US-2021-169551          Rob Lucas   Philadelphia        Furniture
#
# ...

# %%
df.groupby('category')['sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
df['sales'].resample('ME').sum()
# Out:
# order_date
# 2018-01-31     6300.8470
# 2018-02-28     2606.1900
# 2018-03-31    14959.4920
# 2018-04-30    12186.1830
# 2018-05-31    16591.1650
# 2018-06-30    16082.1746
# 2018-07-31    12810.6950
# 2018-08-31    13743.8835
# 2018-09-30    33367.5588
# 2018-10-31    18386.4870
# 2018-11-30    32182.5537
# 2018-12-31    41477.4185
# 2019-01-31    12343.2316
# 2019-02-28     7258.8660
# 2019-03-31    16064.8530
# 2019-04-30    14848.4185
# 2019-05-31    14080.9405
# 2019-06-30    15524.6870
# 2019-07-31    14877.2450
# 2019-08-31    16175.5302
# 2019-09-30    30841.4530
# 2019-10-31    18787.5325
# 2019-11-30    41964.8605
# 2019-12-31    30263.6672
# 2020-01-31    10558.0390
# 2020-02-29     7725.0160
# 2020-03-31    18750.4000
# 2020-04-30    18453.1300
# 2020-05-31    26134.3220
# 2020-06-30    20697.0180
# 2020-07-31    20150.4650
# 2020-08-31    19088.4183
# 2020-09-30    39293.5129
# 2020-10-31    22444.6760
# 2020-11-30    41271.8048
# 2020-12-31    55676.4510
# ...

# %%
df['sales'].resample('YE').sum().plot()
# Out:
# <Axes: xlabel='order_date'>

# %%
df['sales'].resample('QE').sum().plot()
# Out:
# <Axes: xlabel='order_date'>

# %%
df['profit'].resample('QE').sum().plot(title='my first chart')
# Out:
# <Axes: title={'center': 'my first chart'}, xlabel='order_date'>

# %%
#type casting or converting of data type 
df['sales_int'] = df['sales'].astype('int')
df
# Out:
#                   order_id      customer_name           city         category  \
# order_date
# 2018-09-07  CA-2018-100006        Dennis Kane  New York City       Technology
# 2018-07-08  CA-2018-100090         Ed Braxton  San Francisco        Furniture
# 2018-03-14  CA-2018-100293   Neil Französisch   Jacksonville  Office Supplies
# 2018-01-28  CA-2018-100328    Jasper Cacioppo  New York City  Office Supplies
# 2018-04-08  CA-2018-100363        Jim Mitchum       Glendale  Office Supplies
# ...                    ...                ...            ...              ...
# 2021-11-03  US-2021-168802      Jack O'Briant        Seattle  Office Supplies
# 2021-07-23  US-2021-169320     Lena Hernandez        Elkhart  Office Supplies
# 2021-09-07  US-2021-169488       Allen Armold     Providence  Office Supplies
# 2021-08-28  US-2021-169502  Matthew Grinstein      Milwaukee  Office Supplies
# 2021-07-07  US-2021-169551          Rob Lucas   Philadelphia        Furniture
#
# ...

# %%
df.dtypes
# Out:
# order_id          object
# customer_name     object
# city              object
# category          object
# product_id        object
# sales            float64
# profit           float64
# sales_int          int64
# dtype: object

# %%
df.pivot_table(index='city',columns='category',values='sales',aggfunc='min')
# Out:
# category     Furniture  Office Supplies  Technology
# city
# Aberdeen           NaN           25.500         NaN
# Abilene            NaN            1.392         NaN
# Akron          149.232            5.742     279.960
# Albuquerque        NaN            4.280     302.376
# Alexandria      12.420           22.960         NaN
# ...                ...              ...         ...
# Woonsocket      52.960           45.780         NaN
# Yonkers         14.890           10.896      52.440
# York           422.058           37.896         NaN
# Yucaipa            NaN           50.800         NaN
# Yuma               NaN           10.496     185.528
#
# [531 rows x 3 columns]
