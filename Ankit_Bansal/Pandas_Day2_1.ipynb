# %%
import pandas as pd
emp= {"name":["Ankit","Rahul","Priya"],"gender":["Male","Male","Female"], "email":["ankit@gmail.com","rahul@gmail.com","priya@gmail.com"] }
emp
# Out:
# {'name': ['Ankit', 'Rahul', 'Priya'],
#  'gender': ['Male', 'Male', 'Female'],
#  'email': ['ankit@gmail.com', 'rahul@gmail.com', 'priya@gmail.com']}

# %%
df = pd.DataFrame(emp)
df
# Out:
#     name  gender            email
# 0  Ankit    Male  ankit@gmail.com
# 1  Rahul    Male  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
fc = (df['name']=='Ankit')
df[fc]
df.loc[0]
# Out:
# name                Ankit
# gender               Male
# email     ankit@gmail.com
# Name: 0, dtype: object

# %%
#acessing the element using filter condition
print(df.loc[fc])
print(df.loc[fc,'gender'])
# Out:
#     name gender            email
# 0  Ankit   Male  ankit@gmail.com
# 0    Male
# Name: gender, dtype: object

# %%
df.index =['a','b','c']
df
# Out:
#     name  gender            email
# a  Ankit    Male  ankit@gmail.com
# b  Rahul    Male  rahul@gmail.com
# c  Priya  Female  priya@gmail.com

# %%
df.index =[0,1,2]
df
# Out:
#     name  gender            email
# 0  Ankit    Male  ankit@gmail.com
# 1  Rahul    Male  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
df.columns
# Out:
# Index(['name', 'gender', 'email'], dtype='object')

# %%
df.columns = ('emp_name','gender','emp_email')

# %%
df
# Out:
#   emp_name  gender        emp_email
# 0    Ankit    Male  ankit@gmail.com
# 1    Rahul    Male  rahul@gmail.com
# 2    Priya  Female  priya@gmail.com

# %%
df.rename(columns={'emp_name':'name','emp_email':'email'})
# Out:
#     name  gender            email
# 0  Ankit    Male  ankit@gmail.com
# 1  Rahul    Male  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
df.loc[0]=['Ankitt','Male','hapiness@gmail.com']

# %%
df
# Out:
#      name  gender               email
# 0  Ankitt    Male  hapiness@gmail.com
# 1   Rahul    Male     rahul@gmail.com
# 2   Priya  Female     priya@gmail.com

# %%
df.loc[0,'name']='Ankit'

# %%
df
# Out:
#     name  gender               email
# 0  Ankit    Male  hapiness@gmail.com
# 1  Rahul    Male     rahul@gmail.com
# 2  Priya  Female     priya@gmail.com

# %%
df.loc[0,['name','email']]=['Ankit','ankit@gmail.com']

# %%
df
# Out:
#     name  gender            email
# 0  Ankit    Male  ankit@gmail.com
# 1  Rahul    Male  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
fc=(df['gender']=='Male')

# %%
fc
# Out:
# 0     True
# 1     True
# 2    False
# Name: gender, dtype: bool

# %%
df.loc[fc]
# Out:
#     name gender            email
# 0  Ankit   Male  ankit@gmail.com
# 1  Rahul   Male  rahul@gmail.com

# %%
fc=(df['gender']=='Male')
df.loc[fc,'gender']='Female'

# %%
df
# Out:
#     name  gender            email
# 0  Ankit  Female  ankit@gmail.com
# 1  Rahul  Female  rahul@gmail.com
# 2  Priya  Female  priya@gmail.com

# %%
df['gender'].apply(len)
# Out:
# 0    6
# 1    6
# 2    6
# Name: gender, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    ANKIT@GMAIL.COM
# 1    RAHUL@GMAIL.COM
# 2    PRIYA@GMAIL.COM
# Name: email, dtype: object

# %%
df.applymap(len)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_14320\1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    name  gender  email
# 0     5       6     15
# 1     5       6     15
# 2     5       6     15

# %%
df.applymap(update_email)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_14320\2509261660.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(update_email)
#     name  gender            email
# 0  ANKIT  FEMALE  ANKIT@GMAIL.COM
# 1  RAHUL  FEMALE  RAHUL@GMAIL.COM
# 2  PRIYA  FEMALE  PRIYA@GMAIL.COM

# %%
df['name'].str.upper()
# Out:
# 0    ANKIT
# 1    RAHUL
# 2    PRIYA
# Name: name, dtype: object

# %%
df['name'].str.lower()
# Out:
# 0    ankit
# 1    rahul
# 2    priya
# Name: name, dtype: object

# %%
df['name'].str.contains('A')
# Out:
# 0     True
# 1    False
# 2    False
# Name: name, dtype: bool

# %%
df['name'].str.startswith('A')
# Out:
# 0     True
# 1    False
# 2    False
# Name: name, dtype: bool

# %%
#creating a new column
df['salary']=10000
df
# Out:
#     name  gender            email   name_gender  salary  salary1
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   10000    60000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000

# %%
df['name_gender']=df['name']+' '+df['gender']

# %%
df
# Out:
#     name  gender            email   name_gender  salary  salary1
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   10000    60000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000

# %%
df.loc[0,'salary']=20000
df
# Out:
#     name  gender            email   name_gender  salary  salary1
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   20000    60000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000

# %%
df.loc[(df['name']=='Ankit'),'salary']=30000
df
# Out:
#     name  gender            email   name_gender  salary  salary1
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   30000    60000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000

# %%
df['salary1']=[60000,70000,80000]
df
# Out:
#     name  gender            email   name_gender  salary  salary1
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   30000    60000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000

# %%
#delete rows 
df.drop(index =0)
#for change in the original data frame we have to use the inplace=True
#df.drop(index=0,inplace=True
# Out:
#     name  gender            email   name_gender  salary  salary1
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000

# %%
print(df)
fc = (df['salary1']>60000)
fc
# Out:
#     name  gender            email   name_gender  salary  salary1
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   30000    60000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000
# 0    False
# 1     True
# 2     True
# Name: salary1, dtype: bool

# %%
#delete column 
df.drop(columns='salary1')
# Out:
#     name  gender            email   name_gender  salary
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   30000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000

# %%
df.sort_values(by='name',inplace=True)

# %%
df
# Out:
#     name  gender            email   name_gender  salary  salary1
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   30000    60000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000

# %%
df.sort_values(by='salary1',ascending =False)
# Out:
#     name  gender            email   name_gender  salary  salary1
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   30000    60000

# %%
df.sort_values(by=['gender','salary1'],ascending =False,inplace=True)

# %%
df
# Out:
#     name  gender            email   name_gender  salary  salary1
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   30000    60000
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000

# %%
df.sort_index(ascending =False)
# Out:
#     name  gender            email   name_gender  salary  salary1
# 2  Priya  Female  priya@gmail.com  Priya Female   10000    80000
# 1  Rahul    Male  rahul@gmail.com    Rahul Male   10000    70000
# 0  Ankit    Male  ankit@gmail.com    Ankit Male   30000    60000
