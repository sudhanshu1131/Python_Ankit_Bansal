# %%
import pandas as pd

# %%
df= pd.read_csv('orders.txt')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
print(df.head(10))
print(df.tail(10))
# Out:
#          order_id  order_date     customer_name           city  \
# 0  CA-2018-100006  2018-09-07       Dennis Kane  New York City
# 1  CA-2018-100090  2018-07-08        Ed Braxton  San Francisco
# 2  CA-2018-100293  2018-03-14  Neil Französisch   Jacksonville
# 3  CA-2018-100328  2018-01-28   Jasper Cacioppo  New York City
# 4  CA-2018-100363  2018-04-08       Jim Mitchum       Glendale
# 5  CA-2018-100391  2018-05-25     Barry Weirich  New York City
# 6  CA-2018-100678  2018-04-18      Kunst Miller        Houston
# 7  CA-2018-100706  2018-12-16   Laurel Elliston    Springfield
# 8  CA-2018-100762  2018-11-24        Nat Gilpin        Jackson
# 9  CA-2018-100860  2018-03-26     Cindy Stewart         Pomona
#
#           category       product_id    sales    profit
# 0       Technology  TEC-PH-10002075  377.970  109.6113
# 1        Furniture  FUR-TA-10003715  502.488  -87.9354
# 2  Office Supplies  OFF-PA-10000176   91.056   31.8696
# ...

# %%
df['order_id']
# Out:
# 0       CA-2018-100006
# 1       CA-2018-100090
# 2       CA-2018-100293
# 3       CA-2018-100328
# 4       CA-2018-100363
#              ...
# 5004    US-2021-168802
# 5005    US-2021-169320
# 5006    US-2021-169488
# 5007    US-2021-169502
# 5008    US-2021-169551
# Name: order_id, Length: 5009, dtype: object

# %%
col=['order_id','order_date','category']
df[col]
# Out:
#             order_id  order_date         category
# 0     CA-2018-100006  2018-09-07       Technology
# 1     CA-2018-100090  2018-07-08        Furniture
# 2     CA-2018-100293  2018-03-14  Office Supplies
# 3     CA-2018-100328  2018-01-28  Office Supplies
# 4     CA-2018-100363  2018-04-08  Office Supplies
# ...              ...         ...              ...
# 5004  US-2021-168802  2021-11-03  Office Supplies
# 5005  US-2021-169320  2021-07-23  Office Supplies
# 5006  US-2021-169488  2021-09-07  Office Supplies
# 5007  US-2021-169502  2021-08-28  Office Supplies
# 5008  US-2021-169551  2021-07-07        Furniture
#
# [5009 rows x 3 columns]

# %%
#another way of method to use multiple columns
df[['order_id','order_date','category']]
# Out:
#             order_id  order_date         category
# 0     CA-2018-100006  2018-09-07       Technology
# 1     CA-2018-100090  2018-07-08        Furniture
# 2     CA-2018-100293  2018-03-14  Office Supplies
# 3     CA-2018-100328  2018-01-28  Office Supplies
# 4     CA-2018-100363  2018-04-08  Office Supplies
# ...              ...         ...              ...
# 5004  US-2021-168802  2021-11-03  Office Supplies
# 5005  US-2021-169320  2021-07-23  Office Supplies
# 5006  US-2021-169488  2021-09-07  Office Supplies
# 5007  US-2021-169502  2021-08-28  Office Supplies
# 5008  US-2021-169551  2021-07-07        Furniture
#
# [5009 rows x 3 columns]

# %%
df.iloc[[0,2,4],0]
# Out:
# 0    CA-2018-100006
# 2    CA-2018-100293
# 4    CA-2018-100363
# Name: order_id, dtype: object

# %%
df.iloc[2:6,1:3]
# Out:
#    order_date     customer_name
# 2  2018-03-14  Neil Französisch
# 3  2018-01-28   Jasper Cacioppo
# 4  2018-04-08       Jim Mitchum
# 5  2018-05-25     Barry Weirich

# %%
df.loc[2:6,['city','sales']]
# Out:
#             city    sales
# 2   Jacksonville   91.056
# 3  New York City    3.928
# 4       Glendale    2.368
# 5  New York City   14.620
# 6        Houston  317.058

# %%
#to get unique value of a column
df['category'].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
df['category'].value_counts()
# Out:
# category
# Office Supplies    2773
# Furniture          1764
# Technology          472
# Name: count, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# New York City    450
# Los Angeles      384
# Philadelphia     265
# San Francisco    265
# Seattle          212
#                 ...
# Burbank            1
# Glenview           1
# Jupiter            1
# Ormond Beach       1
# Elkhart            1
# Name: count, Length: 531, dtype: int64

# %%
df[['category','city']].value_counts()
# Out:
# category         city
# Office Supplies  New York City    257
#                  Los Angeles      210
# Furniture        New York City    157
# Office Supplies  Philadelphia     152
#                  San Francisco    149
#                                  ...
# Furniture        Boise              1
#                  Bossier City       1
# Technology       Thousand Oaks      1
#                  Toledo             1
#                  Spokane            1
# Name: count, Length: 987, dtype: int64

# %%
fc = (df.category=='Furniture')

# %%
df[fc]
# Out:
#             order_id  order_date       customer_name           city  \
# 1     CA-2018-100090  2018-07-08          Ed Braxton  San Francisco
# 6     CA-2018-100678  2018-04-18        Kunst Miller        Houston
# 7     CA-2018-100706  2018-12-16     Laurel Elliston    Springfield
# 13    CA-2018-100916  2018-10-21        Frank Hawley   Newport News
# 21    CA-2018-101462  2018-04-20  Benjamin Patterson    Los Angeles
# ...              ...         ...                 ...            ...
# 4997  US-2021-167318  2021-07-26     George Zrebassa    Los Angeles
# 4998  US-2021-167402  2021-01-13      Cathy Prescott    Springfield
# 4999  US-2021-167570  2021-12-08         Emily Grady   Philadelphia
# 5002  US-2021-168613  2021-10-08         Gary McGarr  New York City
# 5008  US-2021-169551  2021-07-07           Rob Lucas   Philadelphia
#
#        category       product_id    sales    profit
# 1     Furniture  FUR-TA-10003715  502.488  -87.9354
# ...

# %%
fc1 = (df.category=='Furniture')&(df.sales >= 2000)

# %%
df[fc1]
# Out:
#             order_id  order_date        customer_name           city  \
# 207   CA-2018-116246  2018-09-12           Luke Weiss  New York City
# 245   CA-2018-120474  2018-12-01         Resi Pölking        Madison
# 352   CA-2018-128209  2018-11-17            Greg Tran        Buffalo
# 395   CA-2018-131926  2018-06-01        Dianna Wilson      Lakeville
# 776   CA-2018-167199  2018-01-06        Maria Etezadi      Henderson
# 943   CA-2019-111038  2019-12-01      Lindsay Castell      San Diego
# 1020  CA-2019-116638  2019-01-28          Joseph Holt        Concord
# 1025  CA-2019-117086  2019-11-08         Quincy Jones     Burlington
# 1066  CA-2019-120677  2019-05-31       Bill Donatelli    Minneapolis
# 1293  CA-2019-137113  2019-12-01    Tamara Willingham        Seattle
# 1324  CA-2019-139731  2019-10-15           Joel Eaton       Amarillo
# 1591  CA-2019-160227  2019-11-02         Emily Ducich  New York City
# 1637  CA-2019-164301  2019-03-26        Ellis Ballard        Seattle
# ...

# %%
fc = ~((df.category=='Furniture')&(df.sales >= 2000))
df[fc]
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
df_fur=df[fc1]

# %%
df_fur
# Out:
#             order_id  order_date        customer_name           city  \
# 207   CA-2018-116246  2018-09-12           Luke Weiss  New York City
# 245   CA-2018-120474  2018-12-01         Resi Pölking        Madison
# 352   CA-2018-128209  2018-11-17            Greg Tran        Buffalo
# 395   CA-2018-131926  2018-06-01        Dianna Wilson      Lakeville
# 776   CA-2018-167199  2018-01-06        Maria Etezadi      Henderson
# 943   CA-2019-111038  2019-12-01      Lindsay Castell      San Diego
# 1020  CA-2019-116638  2019-01-28          Joseph Holt        Concord
# 1025  CA-2019-117086  2019-11-08         Quincy Jones     Burlington
# 1066  CA-2019-120677  2019-05-31       Bill Donatelli    Minneapolis
# 1293  CA-2019-137113  2019-12-01    Tamara Willingham        Seattle
# 1324  CA-2019-139731  2019-10-15           Joel Eaton       Amarillo
# 1591  CA-2019-160227  2019-11-02         Emily Ducich  New York City
# 1637  CA-2019-164301  2019-03-26        Ellis Ballard        Seattle
# ...

# %%
df_fur.reset_index(inplace=True)

# %%
df_fur
# Out:
#     index        order_id  order_date        customer_name           city  \
# 0     207  CA-2018-116246  2018-09-12           Luke Weiss  New York City
# 1     245  CA-2018-120474  2018-12-01         Resi Pölking        Madison
# 2     352  CA-2018-128209  2018-11-17            Greg Tran        Buffalo
# 3     395  CA-2018-131926  2018-06-01        Dianna Wilson      Lakeville
# 4     776  CA-2018-167199  2018-01-06        Maria Etezadi      Henderson
# 5     943  CA-2019-111038  2019-12-01      Lindsay Castell      San Diego
# 6    1020  CA-2019-116638  2019-01-28          Joseph Holt        Concord
# 7    1025  CA-2019-117086  2019-11-08         Quincy Jones     Burlington
# 8    1066  CA-2019-120677  2019-05-31       Bill Donatelli    Minneapolis
# 9    1293  CA-2019-137113  2019-12-01    Tamara Willingham        Seattle
# 10   1324  CA-2019-139731  2019-10-15           Joel Eaton       Amarillo
# 11   1591  CA-2019-160227  2019-11-02         Emily Ducich  New York City
# ...

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
fc=(df.category=='Furniture') | (df.category == 'Technology')

# %%
df[fc]
# Out:
#             order_id  order_date           customer_name              city  \
# 0     CA-2018-100006  2018-09-07             Dennis Kane     New York City
# 1     CA-2018-100090  2018-07-08              Ed Braxton     San Francisco
# 6     CA-2018-100678  2018-04-18            Kunst Miller           Houston
# 7     CA-2018-100706  2018-12-16         Laurel Elliston       Springfield
# 10    CA-2018-100867  2018-10-19       Eugene Hildebrand          Lakewood
# 11    CA-2018-100881  2018-03-28           Daniel Raglin       Albuquerque
# 13    CA-2018-100916  2018-10-21            Frank Hawley      Newport News
# 21    CA-2018-101462  2018-04-20      Benjamin Patterson       Los Angeles
# 22    CA-2018-101476  2018-09-12         Shirley Daniels      New Rochelle
# 23    CA-2018-101560  2018-11-28         Chris Selesnick          Columbia
# 24    CA-2018-101602  2018-12-15           Mick Crebagga           El Paso
# ...

# %%
fc=(df.category=='Furniture') | (df.category == 'Technology')
cat=['Furniture','Technology']
fc1=df['category'].isin(cat)
df[fc1]
# Out:
#             order_id  order_date           customer_name              city  \
# 0     CA-2018-100006  2018-09-07             Dennis Kane     New York City
# 1     CA-2018-100090  2018-07-08              Ed Braxton     San Francisco
# 6     CA-2018-100678  2018-04-18            Kunst Miller           Houston
# 7     CA-2018-100706  2018-12-16         Laurel Elliston       Springfield
# 10    CA-2018-100867  2018-10-19       Eugene Hildebrand          Lakewood
# 11    CA-2018-100881  2018-03-28           Daniel Raglin       Albuquerque
# 13    CA-2018-100916  2018-10-21            Frank Hawley      Newport News
# 21    CA-2018-101462  2018-04-20      Benjamin Patterson       Los Angeles
# 22    CA-2018-101476  2018-09-12         Shirley Daniels      New Rochelle
# 23    CA-2018-101560  2018-11-28         Chris Selesnick          Columbia
# 24    CA-2018-101602  2018-12-15           Mick Crebagga           El Paso
# ...

# %%
fc2=df['category'].isin(cat) & (df['customer_name'] == 'Laurel Elliston')
df[fc2]
# Out:
#             order_id  order_date    customer_name         city    category  \
# 7     CA-2018-100706  2018-12-16  Laurel Elliston  Springfield   Furniture
# 2582  CA-2020-157245  2020-05-19  Laurel Elliston    Arlington   Furniture
# 2990  CA-2021-108329  2021-12-09  Laurel Elliston     Whittier  Technology
# 4938  US-2021-150595  2021-05-22  Laurel Elliston      Chicago   Furniture
#
#            product_id    sales    profit
# 7     FUR-FU-10002268   29.460    9.7218
# 2582  FUR-CH-10003746  641.960  179.7488
# 2990  TEC-PH-10001918  444.768   44.4768
# 4938  FUR-CH-10000513  181.986  -54.5958
